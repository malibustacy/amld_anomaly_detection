# %% [markdown]
# # Introduction
#
# This notebook takes the historical data you have been provided and constructs three models - AutoEncoder, One Class SVM, PCA-based - as an illustration of how you might want to proceed with your own analysis. If you would like to understand more about any of these models please ask any of the workshop coveners.
#
# ## Anomaly Detection
#
# The goal of anomaly detection is to identify example feature sets which look like outliers with respect to the bulk of data. The key assumption is that there are at least two non-overlapping underlying statistical distributions with the exmaples we are interseted in, the anomalies, coming from a rarely sampled distribution with respect to the bulk of the data.
#
# In a real world analysis we would usually not know which data are from which distribution, at least until we start investigating the cause of statistical anomalies in the field through some kind of inspection process. In this workshop you have been provided with inspection results which effectively label the different distributions. That means in principle you can implement a supervised learning approach to get better performance, or at least bias the training data in favour of the distribution you would like to learn in an unsupervised or semi-supervised learning approach. In fact we do the latter in the following workflow by removing the labeled fraud data from the training set.
#
# A genenral lesson is that detection of fraud is a process which will require a feedback loop from inspections in the field to gradually improve model performance. Furthermore as the system you are trying to model is itself intelligent (fraudsters might change their behavior in response to a systematic pattern in inspections, or the inspection results themselve can become corrupt), the system is adversarial. It will therefore be necessary to evolve the modeling strategy in response to changes in the underlying system. You might want to think about the implications for running and managing such a model which is going to indentify future fraud cases.

# %% [markdown]
# # 1. Load and Inspect the Data
#
# First we would like to get a feeling for the data and understand which features may be predictive for the target we are training variable we are training for.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read excel requires python package xlrd
raw_data = pd.read_excel('data/Historic_data_WS_EPFL.xlsx')
print(len(raw_data))
raw_data.head()

# %% [markdown]
# There are 38212 examples and 41 features per example, some categorical and some numeric. The target value we are interested in can be inferred from the column `Inspection Result` so lets look at that column in more detail:

# %%
print(raw_data['Inspection Result'].value_counts())
# Out:
# No Violation Issued    25737
# Pass                   12277
# Violation Issued         344
# Warning                   32
# Fail                      22
# Name: Inspection Result, dtype: int64

# %% [markdown]
# It looks like we can further refine these categories into two classes, `normal` and `fraud`, given that e.g., `Pass` and `No Violation Issued` are likely synonymous. Let's add a new variable `class` which assigns this binary label:

# %%
# create the column 'class' from the column 'Inspection Result'
raw_data['class'] = ['normal' if ires in ['No Violation Issued','Pass'] else 'fraud' 
                     for ires in raw_data['Inspection Result']]

# %% [markdown]
# Let's now look at the balance of our binary labels:

# %%
# display fraction of each binary label
print(raw_data['class'].value_counts(normalize=True))
# Out:
# normal    0.989639
# fraud     0.010361
# Name: class, dtype: float64

# %% [markdown]
# It looks like frauds are occuring in about 1% of cases. Given this, and given that we have the luxury of inspection result information to give us this information in the first place, a reasonable approach might be to model the distribution of normal data as well as possible and then use a hypthesis test to see if any new example was indeed drawn from that distribution. Note that we are assuming that inspection results are 100% reliable - no one has been paying off a corrupt inspector to get a favorable report.

# %% [markdown]
# Next let's inspect the other features and see which may be useful as input to a model:

# %%
print("\n##### HAS NULL VALUES #####\n")
print(raw_data.drop(['class', 'Inspection Result'], axis=1).isnull().any())
print("\n##### DATA TYPES #####\n")
print(raw_data.drop(['class', 'Inspection Result'], axis=1).dtypes)
print("\n##### UNIQUE ENTRIES #####\n")
print(raw_data.nunique())
# Out:
# ##### HAS NULL VALUES #####
#
# Record ID             False
# Certificate Number    False
# Business Name          True
# Inspection Date       False
# Borough                True
# Building Number        True
# Street                 True
# Description            True
# City                   True
# State                  True
# Zip                    True
# S1                    False
# S2                    False
# S3                    False
# S4                    False
# S5                    False
# S6                    False
# S7                    False
# S8                    False
# S9                    False
# S10                   False
# S11                   False
# S12                   False
# S13                   False
# S14                   False
# S15                   False
# S16                   False
# S17                   False
# S18                   False
# S19                   False
# S20                   False
# S21                   False
# S22                   False
# S23                   False
# S24                   False
# S25                   False
# S26                   False
# S27                   False
# S28                   False
# Vol                   False
# dtype: bool
#
# ##### DATA TYPES #####
#
# Record ID              object
# Certificate Number     object
# Business Name          object
# Inspection Date        object
# Borough                object
# Building Number        object
# Street                 object
# Description            object
# City                   object
# State                  object
# Zip                   float64
# S1                    float64
# S2                    float64
# S3                    float64
# S4                    float64
# S5                    float64
# S6                    float64
# S7                    float64
# S8                    float64
# S9                    float64
# S10                   float64
# S11                   float64
# S12                   float64
# S13                   float64
# S14                   float64
# S15                   float64
# S16                   float64
# S17                   float64
# S18                   float64
# S19                   float64
# S20                   float64
# S21                   float64
# S22                   float64
# S23                   float64
# S24                   float64
# S25                   float64
# S26                   float64
# S27                   float64
# S28                   float64
# Vol                   float64
# dtype: object
#
# ##### UNIQUE ENTRIES #####
#
# Record ID             37951
# Certificate Number    38361
# Business Name         24762
# Inspection Date         608
# Inspection Result         5
# Borough                  10
# Building Number        7901
# Street                 2087
# Description             306
# City                    138
# State                     8
# Zip                     274
# S1                    37513
# S2                    37513
# S3                    37513
# S4                    37513
# S5                    37513
# S6                    37513
# S7                    37513
# S8                    37513
# S9                    37513
# S10                   37513
# S11                   37513
# S12                   37513
# S13                   37513
# S14                   37513
# S15                   37513
# S16                   37513
# S17                   37513
# S18                   37513
# S19                   37513
# S20                   37513
# S21                   37513
# S22                   37513
# S23                   37513
# S24                   37513
# S25                   37513
# S26                   37513
# S27                   37513
# S28                   37513
# Vol                   10437
# class                     2
# dtype: int64

# %% [markdown]
# We can see that perhaps the numeric data appears to be more reliable that than categorical data. So a reasonable first iteration of the model building process might just proceed with the numeric features: `Vol`, `S1`, `S2`, ..., `S27`, `S28`. If the model turns out not to be performant we can always investigate adding the categorical data as inputs in a second iteration.

# %% [markdown]
# We will now do some basic visualization of the 29 numeric data features to see if there are any indications they might help us identify anomalous feature sets and if they are well suited to being used as input for a multivariate model:

# %%
# plot frequency historgrams of the numerical data
numeric_cols = ['Vol'] + ['S{}'.format(i) for i in range(1,29)]

grid = sns.FacetGrid(pd.melt(raw_data[numeric_cols]), col='variable', col_wrap=5, sharex=False)
grid.map(plt.hist, "value", alpha=.5)
pass

# %% [markdown]
# We can see that several distributions are skewed, this is encouraging as we might expect anomalies to appear in the tails of skewed distributions. If that is the case then it's a reasonable to expect we can train a model with decent performance. We could go further here and explicitly overlay the `normal` and `fraud` data on the same plots to see if there is indeed separation. In fact below we will use a slightly difference method to do this across all the numeric data dimensions.

# %% [markdown]
# Next let's see how correlated the variables are:

# %%
# compute the correlation matrix as a Dataframe
corr_mat = raw_data[numeric_cols].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_mat, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, axes = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_mat, mask=mask, cmap=cmap, vmax=1.0, vmin=-1.0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
pass

# %% [markdown]
# We can see that the correlation between variables is generally low, this is incouraging particularly if we were thinking of doing supervised classification with a random forest.

# %% [markdown]
# If we were to investigate how the categorical data are distributed across the numeric data TSNE is a potential option. We will not perform TSNE here as it can be very computationally expensive, even for this relatively small dataset.
# We would run it as follows:
# ```python
# from sklearn.manifold import TSNE
#
# # transform the numeric data to 2 components
# tsne = TSNE(n_components=2, random_state=11235)
# X_tsne = tsne.fit_transform(raw_data[numeric_cols])
#
# # visualize the t-SNE result
# data_to_plot = pd.concat(
#     [raw_data, pd.DataFrame(X_tsne, columns = ['tsne_x', 'tsne_y'])],
#     axis=1
# )
#
# # for each category of interest plot the TSNE result
# categories = ['Inspection Result', 'Class', 'State', 'Borough']
# for col in cols_overlay:
#     sns.lmplot(
#         x='tsne_x', y='tsne_y',
#         data=data_to_plot, fit_reg=False,
#         hue=col, scatter_kws={'alpha':0.3}, size=10, aspect=1
#     )
# ```

# %% [markdown]
# # 2. Split and Scale the Data
#
# We now need to assign our train, validation and test samples so that we can make fair assessments when deciding which model or set of hyperparameters performs best. Although the data provided can be ordered in time, each example can be thought of as independent so we can randomly split the data. Note that in a lot of anomaly problems time order is important meaning the data separation method will need to be non-random in that case. Please ask one of the conveners if you don't understand why. As mentioned above we are going to use the luxury of our inspection labels to remove the frauds from the training data, if you would like to try and build the model with those still present, which is more challenging but more representative of what a new anomaly detection project might look like then please do!

# %%
from sklearn.model_selection import train_test_split

# fix the random seed for reproducible results
RANDOM_SEED = 1234

# separate the input features and target data into appropriate matrices
X_all = raw_data[numeric_cols].values
y_all = raw_data['class'].values

# first split the train from the test with ratio 2:1 
X_train_all, X_test, y_train_all, y_test = train_test_split(
    X_all, y_all, test_size=0.2, random_state=RANDOM_SEED
)

# further split train into train and validation
X_train, X_val, y_train, y_val, = train_test_split(
    X_train_all, y_train_all, test_size=0.25, random_state=RANDOM_SEED+4321
)

print("TRAIN input shape={}; target shape={}; normal={};  fraud={}"
      .format(X_train.shape, y_train.shape, 
              len(y_train[y_train=='normal']), len(y_train[y_train=='fraud']))
     )
print("VAL   input shape= {}; target shape={};  normal={};   fraud={}"
      .format(X_val.shape, y_val.shape, 
              len(y_val[y_val=='normal']), len(y_val[y_val=='fraud']))
     )
print("TEST  input shape= {}; target shape={};  normal={};   fraud={}"
      .format(X_test.shape, y_test.shape, 
              len(y_test[y_test=='normal']), len(y_test[y_test=='fraud']))
     )
# Out:
# TRAIN input shape=(23046, 29); target shape=(23046,); normal=22818;  fraud=228
# VAL   input shape= (7683, 29); target shape=(7683,);  normal=7603;   fraud=80
# TEST  input shape= (7683, 29); target shape=(7683,);  normal=7593;   fraud=90

# %% [markdown]
# We can see from the frequency histograms that some features have significantly larger ranges than others. We might be able to improve the convergence of gradient descent and associated methods if the features are in the same range. If we are planning to use activations such as sigmoid or tanh in our model we might choose to have the range correspond to the dynamic range of those activations. For now we will use the standard scaler but feel free to change this if you want to investigate whether the choice of scaler can improve performance. As the choice of scaler is effectively a tunable hyperparameter we will fit it with the train dataset and then apply it to all datasets.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# We also save the scaler to disk as we will need it to make predictions in a production environment:

# %%
from sklearn.externals import joblib

joblib.dump(scaler, 'scaler.model')
pass

# %% [markdown]
# # 3. Model Training
#
# We will try three model strategies for our anomaly detection:
# * Autoencoder implemented with Keras with tensorflow backend
# * One Class SVM implemented with scikit-learn
# * PCA deconstruction and inverse implemented with scikit-learn

# %% [markdown]
# ## Autoencoder
#
# The autoencoder model aims to derive a data driven representation of the identity function. Given that by far the majority of the training data are of class `normal` we might expect this identity mapping to perform well for that class and less well for the class where we have far fewer training examples. It follows that if we calculate the performance of the mapping using, e.g., mean squared error, and determine the 99% quantile of the performance we might start to identify the `fraud` class. Let's see how it performs:

# %% [markdown]
# First we construct the model. We will use a shallow autoencoder with no hyperparameter optimization (the setup of the hidden layer is fairly arbitrary and there may be significant room for improvement). As the model will have number of parameters comparable to a significant fraction of the training dataset we feel it's necessary to implement regularization to avoid overfitting; we use simple L1 but it might be interesting to see if dropout can improve performance:

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers
import keras.backend as K

K.clear_session()

# input layer of 29 numeric features
input_layer = Input(shape=(29, ))

# encoding layer with arbitrary hyperparameters and L1 regularization
encoder = Dense(
    20, activation="relu",
    activity_regularizer=regularizers.l1(10e-5)
)(input_layer)

# decoding layer
decoder = Dense(29, activation='relu')(encoder)

# book the model and summarize 
autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 29)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                600
# _________________________________________________________________
# dense_2 (Dense)              (None, 29)                609
# =================================================================
# Total params: 1,209
# Trainable params: 1,209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next configure and train the model, we will save the model for later use, note this introduces a hidden dependency to `h5py`:

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard

# require model be saved and logged
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

# compile the model for training
autoencoder.compile(optimizer='adam', loss='mean_squared_error', 
                    metrics=['mae', 'acc'])

n_epochs = 100
batch_size = 64

# train
history = (
    autoencoder.fit(
        X_train_scaled, X_train_scaled,
        epochs=n_epochs,
        batch_size=batch_size,
        shuffle=True,
        verbose=1,
        validation_data=[X_val_scaled, X_val_scaled],
        callbacks=[checkpointer, tensorboard]
    ).history
)
# Out:
# Train on 23046 samples, validate on 7683 samples
# Epoch 1/100
# 23046/23046 [==============================] - 1s 41us/step - loss: 1.0133 - mean_absolute_error: 0.6071 - acc: 0.2157 - val_loss: 0.8963 - val_mean_absolute_error: 0.5729 - val_acc: 0.3841
# Epoch 2/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.8434 - mean_absolute_error: 0.5503 - acc: 0.4544 - val_loss: 0.8166 - val_mean_absolute_error: 0.5365 - val_acc: 0.5007
# Epoch 3/100
# 23046/23046 [==============================] - 2s 92us/step - loss: 0.7783 - mean_absolute_error: 0.5211 - acc: 0.5470 - val_loss: 0.7725 - val_mean_absolute_error: 0.5136 - val_acc: 0.5765
# Epoch 4/100
# 23046/23046 [==============================] - 1s 29us/step - loss: 0.7448 - mean_absolute_error: 0.5012 - acc: 0.5956 - val_loss: 0.7479 - val_mean_absolute_error: 0.4958 - val_acc: 0.6098
# Epoch 5/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.7249 - mean_absolute_error: 0.4860 - acc: 0.6250 - val_loss: 0.7326 - val_mean_absolute_error: 0.4827 - val_acc: 0.6375
# Epoch 6/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.7103 - mean_absolute_error: 0.4732 - acc: 0.6470 - val_loss: 0.7185 - val_mean_absolute_error: 0.4706 - val_acc: 0.6626
# Epoch 7/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6993 - mean_absolute_error: 0.4629 - acc: 0.6711 - val_loss: 0.7094 - val_mean_absolute_error: 0.4619 - val_acc: 0.6807
# Epoch 8/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6908 - mean_absolute_error: 0.4548 - acc: 0.6931 - val_loss: 0.7011 - val_mean_absolute_error: 0.4546 - val_acc: 0.6969
# Epoch 9/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6829 - mean_absolute_error: 0.4476 - acc: 0.7093 - val_loss: 0.6930 - val_mean_absolute_error: 0.4476 - val_acc: 0.7168
# Epoch 10/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6751 - mean_absolute_error: 0.4406 - acc: 0.7252 - val_loss: 0.6858 - val_mean_absolute_error: 0.4405 - val_acc: 0.7337
# Epoch 11/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6669 - mean_absolute_error: 0.4346 - acc: 0.7380 - val_loss: 0.6778 - val_mean_absolute_error: 0.4362 - val_acc: 0.7416
# Epoch 12/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6602 - mean_absolute_error: 0.4304 - acc: 0.7468 - val_loss: 0.6715 - val_mean_absolute_error: 0.4319 - val_acc: 0.7487
# Epoch 13/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6553 - mean_absolute_error: 0.4270 - acc: 0.7538 - val_loss: 0.6677 - val_mean_absolute_error: 0.4290 - val_acc: 0.7549
# Epoch 14/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6517 - mean_absolute_error: 0.4244 - acc: 0.7590 - val_loss: 0.6644 - val_mean_absolute_error: 0.4267 - val_acc: 0.7591
# Epoch 15/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6487 - mean_absolute_error: 0.4221 - acc: 0.7656 - val_loss: 0.6614 - val_mean_absolute_error: 0.4245 - val_acc: 0.7651
# Epoch 16/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6460 - mean_absolute_error: 0.4201 - acc: 0.7682 - val_loss: 0.6592 - val_mean_absolute_error: 0.4226 - val_acc: 0.7704
# Epoch 17/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6435 - mean_absolute_error: 0.4183 - acc: 0.7720 - val_loss: 0.6567 - val_mean_absolute_error: 0.4206 - val_acc: 0.7738
# Epoch 18/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6419 - mean_absolute_error: 0.4169 - acc: 0.7741 - val_loss: 0.6554 - val_mean_absolute_error: 0.4198 - val_acc: 0.7718
# Epoch 19/100
# 23046/23046 [==============================] - 1s 34us/step - loss: 0.6395 - mean_absolute_error: 0.4154 - acc: 0.7782 - val_loss: 0.6532 - val_mean_absolute_error: 0.4184 - val_acc: 0.7746
# Epoch 20/100
# 23046/23046 [==============================] - 1s 40us/step - loss: 0.6376 - mean_absolute_error: 0.4142 - acc: 0.7787 - val_loss: 0.6506 - val_mean_absolute_error: 0.4167 - val_acc: 0.7770
# Epoch 21/100
# 23046/23046 [==============================] - 1s 44us/step - loss: 0.6358 - mean_absolute_error: 0.4129 - acc: 0.7805 - val_loss: 0.6493 - val_mean_absolute_error: 0.4158 - val_acc: 0.7756
# Epoch 22/100
# 23046/23046 [==============================] - 3s 143us/step - loss: 0.6342 - mean_absolute_error: 0.4119 - acc: 0.7800 - val_loss: 0.6471 - val_mean_absolute_error: 0.4142 - val_acc: 0.7789
# Epoch 23/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6323 - mean_absolute_error: 0.4105 - acc: 0.7818 - val_loss: 0.6455 - val_mean_absolute_error: 0.4132 - val_acc: 0.7794
# Epoch 24/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6312 - mean_absolute_error: 0.4098 - acc: 0.7849 - val_loss: 0.6453 - val_mean_absolute_error: 0.4130 - val_acc: 0.7748
# Epoch 25/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6300 - mean_absolute_error: 0.4090 - acc: 0.7825 - val_loss: 0.6424 - val_mean_absolute_error: 0.4114 - val_acc: 0.7830
# Epoch 26/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6281 - mean_absolute_error: 0.4077 - acc: 0.7864 - val_loss: 0.6415 - val_mean_absolute_error: 0.4102 - val_acc: 0.7873
# Epoch 27/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6272 - mean_absolute_error: 0.4070 - acc: 0.7874 - val_loss: 0.6400 - val_mean_absolute_error: 0.4097 - val_acc: 0.7894
# Epoch 28/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6260 - mean_absolute_error: 0.4061 - acc: 0.7886 - val_loss: 0.6410 - val_mean_absolute_error: 0.4105 - val_acc: 0.7869
# Epoch 29/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6246 - mean_absolute_error: 0.4052 - acc: 0.7905 - val_loss: 0.6376 - val_mean_absolute_error: 0.4074 - val_acc: 0.7923
# Epoch 30/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6234 - mean_absolute_error: 0.4042 - acc: 0.7915 - val_loss: 0.6377 - val_mean_absolute_error: 0.4080 - val_acc: 0.7889
# Epoch 31/100
# 23046/23046 [==============================] - 1s 31us/step - loss: 0.6227 - mean_absolute_error: 0.4038 - acc: 0.7927 - val_loss: 0.6365 - val_mean_absolute_error: 0.4065 - val_acc: 0.7951
# Epoch 32/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6219 - mean_absolute_error: 0.4030 - acc: 0.7954 - val_loss: 0.6355 - val_mean_absolute_error: 0.4061 - val_acc: 0.7946
# Epoch 33/100
# 23046/23046 [==============================] - 1s 43us/step - loss: 0.6208 - mean_absolute_error: 0.4022 - acc: 0.7971 - val_loss: 0.6352 - val_mean_absolute_error: 0.4060 - val_acc: 0.7960
# Epoch 34/100
# 23046/23046 [==============================] - 1s 42us/step - loss: 0.6202 - mean_absolute_error: 0.4017 - acc: 0.7963 - val_loss: 0.6335 - val_mean_absolute_error: 0.4040 - val_acc: 0.7967
# Epoch 35/100
# 23046/23046 [==============================] - 2s 108us/step - loss: 0.6191 - mean_absolute_error: 0.4006 - acc: 0.8003 - val_loss: 0.6328 - val_mean_absolute_error: 0.4035 - val_acc: 0.7988
# Epoch 36/100
# 23046/23046 [==============================] - 1s 50us/step - loss: 0.6185 - mean_absolute_error: 0.4002 - acc: 0.7991 - val_loss: 0.6318 - val_mean_absolute_error: 0.4030 - val_acc: 0.7999
# Epoch 37/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6175 - mean_absolute_error: 0.3994 - acc: 0.8007 - val_loss: 0.6314 - val_mean_absolute_error: 0.4027 - val_acc: 0.8029
# Epoch 38/100
# 23046/23046 [==============================] - 1s 34us/step - loss: 0.6166 - mean_absolute_error: 0.3986 - acc: 0.8047 - val_loss: 0.6302 - val_mean_absolute_error: 0.4015 - val_acc: 0.8031
# Epoch 39/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6161 - mean_absolute_error: 0.3980 - acc: 0.8033 - val_loss: 0.6294 - val_mean_absolute_error: 0.4008 - val_acc: 0.8087
# Epoch 40/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6157 - mean_absolute_error: 0.3977 - acc: 0.8054 - val_loss: 0.6294 - val_mean_absolute_error: 0.4010 - val_acc: 0.8071
# Epoch 41/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6147 - mean_absolute_error: 0.3969 - acc: 0.8073 - val_loss: 0.6281 - val_mean_absolute_error: 0.3998 - val_acc: 0.8114
# Epoch 42/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6139 - mean_absolute_error: 0.3963 - acc: 0.8078 - val_loss: 0.6296 - val_mean_absolute_error: 0.4025 - val_acc: 0.8005
# Epoch 43/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6135 - mean_absolute_error: 0.3960 - acc: 0.8099 - val_loss: 0.6271 - val_mean_absolute_error: 0.3996 - val_acc: 0.8067
# Epoch 44/100
# 23046/23046 [==============================] - 1s 29us/step - loss: 0.6133 - mean_absolute_error: 0.3963 - acc: 0.8094 - val_loss: 0.6260 - val_mean_absolute_error: 0.3977 - val_acc: 0.8102
# Epoch 45/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6121 - mean_absolute_error: 0.3947 - acc: 0.8121 - val_loss: 0.6254 - val_mean_absolute_error: 0.3972 - val_acc: 0.8161
# Epoch 46/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6122 - mean_absolute_error: 0.3948 - acc: 0.8110 - val_loss: 0.6258 - val_mean_absolute_error: 0.3981 - val_acc: 0.8141
# Epoch 47/100
# 23046/23046 [==============================] - 1s 29us/step - loss: 0.6111 - mean_absolute_error: 0.3939 - acc: 0.8152 - val_loss: 0.6249 - val_mean_absolute_error: 0.3971 - val_acc: 0.8158
# Epoch 48/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6110 - mean_absolute_error: 0.3938 - acc: 0.8132 - val_loss: 0.6247 - val_mean_absolute_error: 0.3968 - val_acc: 0.8141
# Epoch 49/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6111 - mean_absolute_error: 0.3936 - acc: 0.8133 - val_loss: 0.6237 - val_mean_absolute_error: 0.3958 - val_acc: 0.8210
# Epoch 50/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6096 - mean_absolute_error: 0.3924 - acc: 0.8156 - val_loss: 0.6231 - val_mean_absolute_error: 0.3949 - val_acc: 0.8230
# Epoch 51/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6095 - mean_absolute_error: 0.3923 - acc: 0.8175 - val_loss: 0.6223 - val_mean_absolute_error: 0.3943 - val_acc: 0.8226
# Epoch 52/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6090 - mean_absolute_error: 0.3917 - acc: 0.8174 - val_loss: 0.6222 - val_mean_absolute_error: 0.3943 - val_acc: 0.8272
# Epoch 53/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6089 - mean_absolute_error: 0.3914 - acc: 0.8176 - val_loss: 0.6218 - val_mean_absolute_error: 0.3938 - val_acc: 0.8247
# Epoch 54/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6083 - mean_absolute_error: 0.3911 - acc: 0.8207 - val_loss: 0.6218 - val_mean_absolute_error: 0.3932 - val_acc: 0.8232
# Epoch 55/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6081 - mean_absolute_error: 0.3907 - acc: 0.8195 - val_loss: 0.6211 - val_mean_absolute_error: 0.3932 - val_acc: 0.8269
# Epoch 56/100
# 23046/23046 [==============================] - 1s 43us/step - loss: 0.6074 - mean_absolute_error: 0.3902 - acc: 0.8204 - val_loss: 0.6247 - val_mean_absolute_error: 0.3944 - val_acc: 0.8279
# Epoch 57/100
# 23046/23046 [==============================] - 1s 40us/step - loss: 0.6083 - mean_absolute_error: 0.3904 - acc: 0.8208 - val_loss: 0.6206 - val_mean_absolute_error: 0.3919 - val_acc: 0.8274
# Epoch 58/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6070 - mean_absolute_error: 0.3895 - acc: 0.8217 - val_loss: 0.6199 - val_mean_absolute_error: 0.3917 - val_acc: 0.8331
# Epoch 59/100
# 23046/23046 [==============================] - 1s 32us/step - loss: 0.6067 - mean_absolute_error: 0.3888 - acc: 0.8239 - val_loss: 0.6219 - val_mean_absolute_error: 0.3948 - val_acc: 0.8260
# Epoch 60/100
# 23046/23046 [==============================] - 1s 50us/step - loss: 0.6066 - mean_absolute_error: 0.3892 - acc: 0.8255 - val_loss: 0.6201 - val_mean_absolute_error: 0.3924 - val_acc: 0.8292
# Epoch 61/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6059 - mean_absolute_error: 0.3885 - acc: 0.8256 - val_loss: 0.6189 - val_mean_absolute_error: 0.3900 - val_acc: 0.8370
# Epoch 62/100
# 23046/23046 [==============================] - 1s 36us/step - loss: 0.6065 - mean_absolute_error: 0.3886 - acc: 0.8273 - val_loss: 0.6194 - val_mean_absolute_error: 0.3906 - val_acc: 0.8367
# Epoch 63/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6060 - mean_absolute_error: 0.3882 - acc: 0.8268 - val_loss: 0.6182 - val_mean_absolute_error: 0.3897 - val_acc: 0.8337
# Epoch 64/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6052 - mean_absolute_error: 0.3873 - acc: 0.8296 - val_loss: 0.6190 - val_mean_absolute_error: 0.3904 - val_acc: 0.8335
# Epoch 65/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6047 - mean_absolute_error: 0.3872 - acc: 0.8290 - val_loss: 0.6180 - val_mean_absolute_error: 0.3896 - val_acc: 0.8346
# Epoch 66/100
# 23046/23046 [==============================] - 1s 23us/step - loss: 0.6046 - mean_absolute_error: 0.3869 - acc: 0.8310 - val_loss: 0.6180 - val_mean_absolute_error: 0.3895 - val_acc: 0.8376
# Epoch 67/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6050 - mean_absolute_error: 0.3871 - acc: 0.8297 - val_loss: 0.6211 - val_mean_absolute_error: 0.3928 - val_acc: 0.8301
# Epoch 68/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6039 - mean_absolute_error: 0.3860 - acc: 0.8339 - val_loss: 0.6182 - val_mean_absolute_error: 0.3897 - val_acc: 0.8389
# Epoch 69/100
# 23046/23046 [==============================] - 1s 32us/step - loss: 0.6037 - mean_absolute_error: 0.3858 - acc: 0.8354 - val_loss: 0.6184 - val_mean_absolute_error: 0.3893 - val_acc: 0.8390
# Epoch 70/100
# 23046/23046 [==============================] - 1s 34us/step - loss: 0.6045 - mean_absolute_error: 0.3866 - acc: 0.8313 - val_loss: 0.6167 - val_mean_absolute_error: 0.3880 - val_acc: 0.8404
# Epoch 71/100
# 23046/23046 [==============================] - 1s 38us/step - loss: 0.6038 - mean_absolute_error: 0.3859 - acc: 0.8324 - val_loss: 0.6168 - val_mean_absolute_error: 0.3882 - val_acc: 0.8354
# Epoch 72/100
# 23046/23046 [==============================] - 1s 29us/step - loss: 0.6029 - mean_absolute_error: 0.3849 - acc: 0.8345 - val_loss: 0.6166 - val_mean_absolute_error: 0.3891 - val_acc: 0.8393
# Epoch 73/100
# 23046/23046 [==============================] - 1s 42us/step - loss: 0.6029 - mean_absolute_error: 0.3853 - acc: 0.8355 - val_loss: 0.6169 - val_mean_absolute_error: 0.3886 - val_acc: 0.8368
# Epoch 74/100
# 23046/23046 [==============================] - 1s 57us/step - loss: 0.6034 - mean_absolute_error: 0.3855 - acc: 0.8335 - val_loss: 0.6163 - val_mean_absolute_error: 0.3877 - val_acc: 0.8395
# Epoch 75/100
# 23046/23046 [==============================] - 1s 32us/step - loss: 0.6029 - mean_absolute_error: 0.3850 - acc: 0.8359 - val_loss: 0.6178 - val_mean_absolute_error: 0.3910 - val_acc: 0.8347
# Epoch 76/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6028 - mean_absolute_error: 0.3853 - acc: 0.8350 - val_loss: 0.6158 - val_mean_absolute_error: 0.3873 - val_acc: 0.8462
# Epoch 77/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6026 - mean_absolute_error: 0.3850 - acc: 0.8373 - val_loss: 0.6155 - val_mean_absolute_error: 0.3879 - val_acc: 0.8391
# Epoch 78/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6014 - mean_absolute_error: 0.3833 - acc: 0.8379 - val_loss: 0.6193 - val_mean_absolute_error: 0.3897 - val_acc: 0.8415
# Epoch 79/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.6025 - mean_absolute_error: 0.3846 - acc: 0.8362 - val_loss: 0.6187 - val_mean_absolute_error: 0.3896 - val_acc: 0.8321
# Epoch 80/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6061 - mean_absolute_error: 0.3868 - acc: 0.8333 - val_loss: 0.6160 - val_mean_absolute_error: 0.3879 - val_acc: 0.8424
# Epoch 81/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6012 - mean_absolute_error: 0.3829 - acc: 0.8411 - val_loss: 0.6151 - val_mean_absolute_error: 0.3868 - val_acc: 0.8463
# Epoch 82/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6017 - mean_absolute_error: 0.3837 - acc: 0.8397 - val_loss: 0.6148 - val_mean_absolute_error: 0.3870 - val_acc: 0.8494
# Epoch 83/100
# 23046/23046 [==============================] - 1s 28us/step - loss: 0.6008 - mean_absolute_error: 0.3828 - acc: 0.8407 - val_loss: 0.6155 - val_mean_absolute_error: 0.3872 - val_acc: 0.8439
# Epoch 84/100
# 23046/23046 [==============================] - 1s 24us/step - loss: 0.6017 - mean_absolute_error: 0.3838 - acc: 0.8383 - val_loss: 0.6145 - val_mean_absolute_error: 0.3859 - val_acc: 0.8438
# Epoch 85/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6012 - mean_absolute_error: 0.3834 - acc: 0.8403 - val_loss: 0.6151 - val_mean_absolute_error: 0.3863 - val_acc: 0.8490
# Epoch 86/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.6007 - mean_absolute_error: 0.3829 - acc: 0.8417 - val_loss: 0.6133 - val_mean_absolute_error: 0.3848 - val_acc: 0.8403
# Epoch 87/100
# 23046/23046 [==============================] - 1s 41us/step - loss: 0.6012 - mean_absolute_error: 0.3832 - acc: 0.8429 - val_loss: 0.6131 - val_mean_absolute_error: 0.3838 - val_acc: 0.8449
# Epoch 88/100
# 23046/23046 [==============================] - 1s 38us/step - loss: 0.6002 - mean_absolute_error: 0.3822 - acc: 0.8427 - val_loss: 0.6138 - val_mean_absolute_error: 0.3850 - val_acc: 0.8454
# Epoch 89/100
# 23046/23046 [==============================] - 1s 35us/step - loss: 0.6003 - mean_absolute_error: 0.3824 - acc: 0.8439 - val_loss: 0.6129 - val_mean_absolute_error: 0.3833 - val_acc: 0.8490
# Epoch 90/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.5997 - mean_absolute_error: 0.3818 - acc: 0.8432 - val_loss: 0.6163 - val_mean_absolute_error: 0.3880 - val_acc: 0.8390
# Epoch 91/100
# 23046/23046 [==============================] - 1s 29us/step - loss: 0.5998 - mean_absolute_error: 0.3821 - acc: 0.8430 - val_loss: 0.6141 - val_mean_absolute_error: 0.3867 - val_acc: 0.8452
# Epoch 92/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6003 - mean_absolute_error: 0.3829 - acc: 0.8417 - val_loss: 0.6131 - val_mean_absolute_error: 0.3848 - val_acc: 0.8475
# Epoch 93/100
# 23046/23046 [==============================] - 1s 55us/step - loss: 0.5997 - mean_absolute_error: 0.3818 - acc: 0.8431 - val_loss: 0.6141 - val_mean_absolute_error: 0.3864 - val_acc: 0.8467
# Epoch 94/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.6000 - mean_absolute_error: 0.3819 - acc: 0.8460 - val_loss: 0.6160 - val_mean_absolute_error: 0.3876 - val_acc: 0.8503
# Epoch 95/100
# 23046/23046 [==============================] - 1s 30us/step - loss: 0.6003 - mean_absolute_error: 0.3824 - acc: 0.8441 - val_loss: 0.6123 - val_mean_absolute_error: 0.3829 - val_acc: 0.8536
# Epoch 96/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.5990 - mean_absolute_error: 0.3810 - acc: 0.8463 - val_loss: 0.6124 - val_mean_absolute_error: 0.3845 - val_acc: 0.8499
# Epoch 97/100
# 23046/23046 [==============================] - 1s 25us/step - loss: 0.5992 - mean_absolute_error: 0.3816 - acc: 0.8468 - val_loss: 0.6133 - val_mean_absolute_error: 0.3851 - val_acc: 0.8428
# Epoch 98/100
# 23046/23046 [==============================] - 1s 27us/step - loss: 0.5994 - mean_absolute_error: 0.3815 - acc: 0.8434 - val_loss: 0.6133 - val_mean_absolute_error: 0.3846 - val_acc: 0.8460
# Epoch 99/100
# 23046/23046 [==============================] - 1s 26us/step - loss: 0.5987 - mean_absolute_error: 0.3809 - acc: 0.8471 - val_loss: 0.6117 - val_mean_absolute_error: 0.3830 - val_acc: 0.8533
# Epoch 100/100
# 23046/23046 [==============================] - 1s 31us/step - loss: 0.6000 - mean_absolute_error: 0.3820 - acc: 0.8445 - val_loss: 0.6127 - val_mean_absolute_error: 0.3849 - val_acc: 0.8490

# %% [markdown]
# Now we have a trained model let's plot the loss evolution as a function of training input:

# %%
plt.plot(history['val_loss'])
plt.plot(history['loss'])
plt.legend(['val_loss','loss'])
pass

# %% [markdown]
# We can see that there is not too much divergence between the validation and training datasets, and that the curve has started to flatten at higher epochs with respect to the initial twenty. Now we want to use the test data to determine the 99% threshold which assigns an anomaly and see how that impact the performance of anomaly detection on the validation data:

# %%
from keras.models import load_model
from sklearn.metrics import mean_squared_error

K.clear_session()

trained_model = load_model('model.h5')

train_predicted = trained_model.predict(X_train_scaled)

train_mse = mean_squared_error(train_predicted.T, X_train_scaled.T, multioutput='raw_values')

thresh_train = np.percentile(train_mse, 99)
print(thresh_train)
# Out:
# 5.76483787243

# %% [markdown]
# We will first visualize the mse plots for both target classes, and then for the validation data plot the confusion matrix and show precision and recall:

# %%
from sklearn.metrics import precision_score, recall_score
from amld_functions import plot_confmat

# propagate the scaled validation data through prediction workflow
val_predicted = trained_model.predict(X_val_scaled)
val_mse = mean_squared_error(val_predicted.T, X_val_scaled.T, multioutput='raw_values')
val_model_status = ['normal' if imse < thresh_train else 'fraud' for imse in val_mse]

# plot the mse residuals
pred_res = pd.DataFrame(dict(mse=val_mse, label=y_val))
pred_res['index'] = pred_res.index
pred_res.groupby('label')['mse'].apply(np.mean)
fig = sns.lmplot(data=pred_res, x='index', y='mse',
                 hue='label', fit_reg=False, size=5, aspect=2.5)

# plot the confusion matrix
plot_confmat(y_val, val_model_status)

pr = precision_score(y_val, val_model_status, pos_label='fraud')
rc = recall_score(y_val, val_model_status, pos_label='fraud')
print("Precision: {:0.2f}; Recall: {:0.2f}".format(pr, rc))
# Out:
# Precision: 0.45; Recall: 0.50

# %% [markdown]
# We have moderate performance, how might this change if we take advantage of the inspection labels and only train the autoencoder using data from the `normal` class?

# %% [markdown]
# We will not go through the next examples in as much detail, just present the trainind code and validation performance.

# %% [markdown]
# ## One Class SVM
#
# Again keep in mind that there has been no hyperparameter optimization in the following.

# %%
from sklearn.svm import OneClassSVM

# fit the model
mod_svm = OneClassSVM(nu=0.1, kernel='rbf', gamma=0.01)
mod_svm.fit(X_train_scaled)

# predict
val_model_status = ['normal' if ival ==1 else 'fraud' for ival in mod_svm.predict(X_val_scaled)]

#save the model
joblib.dump(mod_svm, 'svm.model')

# plot the confusion matrix
plot_confmat(y_val, val_model_status)

pr = precision_score(y_val, val_model_status, pos_label='fraud')
rc = recall_score(y_val, val_model_status, pos_label='fraud')
print("Precision: {:0.2f}; Recall: {:0.2f}".format(pr, rc))
# Out:
# Precision: 0.10; Recall: 0.90

# %% [markdown]
# ## PCA-Based Anomaly
#
# This uses the same workflow as the autoencoder, we will optimize the downsample step by determine how many components in PCA explain 95% of the variance:

# %%
from sklearn import decomposition

# find number of components retaining 95% variance
pca = decomposition.PCA()
pca.fit(X_train_scaled)

# plot the variance as a function of components
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.title('Cumulative explained variance')

# determine the number of components to use
cum_var = pca.explained_variance_ratio_.cumsum()
num_comp = cum_var[cum_var <= 0.95].argmax()
print('Number of components to be used = {}'.format(num_comp))

# perform PCA decomposition on the train set
pca = decomposition.PCA(n_components=num_comp)
pca.fit(X_train_scaled)

# save the model
joblib.dump(pca, 'pca.model')

pass
# Out:
# Number of components to be used = 23

# %%
# calculate the threshold from the training data

X_train_pca = pca.transform(X_train_scaled)
X_train_projected = pca.inverse_transform(X_train_pca)

X_train_mse = mean_squared_error(X_train_scaled.T, X_train_projected.T, multioutput='raw_values')

thres_pca = np.percentile(X_train_mse, 99)

print(thres_pca)
# Out:
# 0.478859670857

# %%
# propagate the scaled validation data through prediction workflow
val_pca = pca.transform(X_val_scaled)
val_projected = pca.inverse_transform(val_pca)
val_mse = mean_squared_error(val_projected.T, X_val_scaled.T, multioutput='raw_values')
val_model_status = ['normal' if imse < thres_pca else 'fraud' for imse in val_mse]

# plot the mse residuals
pred_res = pd.DataFrame(dict(mse=val_mse, label=y_val))
pred_res['index'] = pred_res.index
pred_res.groupby('label')['mse'].apply(np.mean)
fig = sns.lmplot(data=pred_res, x='index', y='mse',
                 hue='label', fit_reg=False, size=5, aspect=2.5)

# plot the confusion matrix
plot_confmat(y_val, val_model_status)

pr = precision_score(y_val, val_model_status, pos_label='fraud')
rc = recall_score(y_val, val_model_status, pos_label='fraud')
print("Precision: {:0.2f}; Recall: {:0.2f}".format(pr, rc))
# Out:
# Precision: 0.32; Recall: 0.28

# %% [markdown]
# This model is not particularly performant. However, look what happens when we train omitting the fraud examples in the training set:

# %%
# retrain
pca_updated = decomposition.PCA(n_components=num_comp)
pca_updated.fit(X_train_scaled[np.where(y_train=='normal')])

X_train_pca = pca_updated.transform(X_train_scaled)
X_train_projected = pca_updated.inverse_transform(X_train_pca)

X_train_mse = mean_squared_error(X_train_scaled.T, X_train_projected.T, multioutput='raw_values')

thres_pca = np.percentile(X_train_mse, 99)

joblib.dump(pca_updated, 'pca_updated.model')

# propagate the scaled validation data through prediction workflow
val_pca = pca_updated.transform(X_val_scaled)
val_projected = pca_updated.inverse_transform(val_pca)
val_mse = mean_squared_error(val_projected.T, X_val_scaled.T, multioutput='raw_values')
val_model_status = ['normal' if imse < thres_pca else 'fraud' for imse in val_mse]

# plot the mse residuals
pred_res = pd.DataFrame(dict(mse=val_mse, label=y_val))
pred_res['index'] = pred_res.index
pred_res.groupby('label')['mse'].apply(np.mean)
fig = sns.lmplot(data=pred_res, x='index', y='mse',
                 hue='label', fit_reg=False, size=5, aspect=2.5)

# plot the confusion matrix
plot_confmat(y_val, val_model_status)

pr = precision_score(y_val, val_model_status, pos_label='fraud')
rc = recall_score(y_val, val_model_status, pos_label='fraud')
print("Precision: {:0.2f}; Recall: {:0.2f}".format(pr, rc))
# Out:
# Precision: 0.71; Recall: 0.69

# %% [markdown]
# A significant improvement! This final lesson emphasizes how important it can be to work on the data science process iteratively, using feedback from running a non-perfect model in production so that feedback from the field can further improve the model performance.
